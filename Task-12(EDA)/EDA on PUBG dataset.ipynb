# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',30)
pd.set_option('display.max_rows',1111742)

# %%
df=pd.read_csv('pubgdata.csv')

# %% [markdown]
# ### Viewing top 5 rows of the data

# %%
df.head()
# Out:
#    Unnamed: 0              Id         groupId         matchId  assists  \
# 0     2093518  a3e3cea9f2e314  c9f6eaa81245b5  a3d8693390584c        0
# 1     3701672  43e4be7ad72cc7  521836de101ee8  b65de9055327e0        0
# 2     2059784  9a68690e31fdff  4a72ffa2cebd90  d6aad3f9830e60        0
# 3     1302036  b147e1bd448fc4  9a8991656b3fea  d931c0932d8aca        0
# 4      297180  d818b4edd59612  eece87c8b846b3  ec2b5ed94baae3        0
#
#    boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  killPoints  \
# 0       0        25.93      0              0      0         84        1437
# 1       0        36.71      0              0      0         57        1225
# 2       1        47.73      0              0      0         50           0
# 3       0         0.00      0              0      0         56        1286
# 4       2       100.00      0              0      3         31           0
#
#    kills  killStreaks  longestKill  matchDuration  matchType  maxPlace  \
# ...

# %% [markdown]
# ### Droping Unnamed column

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True )

# %% [markdown]
# ### Viewing size of data

# %%
df.shape
# Out:
# (1111742, 29)

# %% [markdown]
# ### Viewing statistical values for numerical values

# %%
df.describe()
# Out:
#             assists        boosts   damageDealt         DBNOs  headshotKills  \
# count  1.111742e+06  1.111742e+06  1.111742e+06  1.111742e+06   1.111742e+06
# mean   2.336738e-01  1.106655e+00  1.307364e+02  6.573612e-01   2.266488e-01
# std    5.894028e-01  1.716050e+00  1.711755e+02  1.146023e+00   6.033356e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    0.000000e+00  0.000000e+00  8.411000e+01  0.000000e+00   0.000000e+00
# 75%    0.000000e+00  2.000000e+00  1.859000e+02  1.000000e+00   0.000000e+00
# max    1.700000e+01  2.400000e+01  5.990000e+03  3.500000e+01   6.400000e+01
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  1.111742e+06  1.111742e+06  1.111742e+06  1.111742e+06  1.111742e+06
# mean   1.370348e+00  4.759562e+01  5.044301e+02  9.255097e-01  5.448503e-01
# ...

# %% [markdown]
# ### Seeing the types of features in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111742 entries, 0 to 1111741
# Data columns (total 29 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Id               1111742 non-null  object
#  1   groupId          1111742 non-null  object
#  2   matchId          1111742 non-null  object
#  3   assists          1111742 non-null  int64
#  4   boosts           1111742 non-null  int64
#  5   damageDealt      1111742 non-null  float64
#  6   DBNOs            1111742 non-null  int64
#  7   headshotKills    1111742 non-null  int64
#  8   heals            1111742 non-null  int64
#  9   killPlace        1111742 non-null  int64
#  10  killPoints       1111742 non-null  int64
#  11  kills            1111742 non-null  int64
#  12  killStreaks      1111742 non-null  int64
#  13  longestKill      1111742 non-null  float64
#  14  matchDuration    1111742 non-null  int64
#  15  matchType        1111742 non-null  object
# ...

# %% [markdown]
# ### Checking for null values

# %%
df.isnull().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       1
# dtype: int64

# %% [markdown]
# ### Filling missing value in winplaceperc with mean

# %%
df['winPlacePerc']=df['winPlacePerc'].fillna(df['winPlacePerc'].mean())

# %%
df.isnull().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       0
# dtype: int64

# %%
df1=df.select_dtypes(include=['float64', 'int64'])
df2=df.select_dtypes(include=['object'])

# %%
df1.columns
# Out:
# Index(['assists', 'boosts', 'damageDealt', 'DBNOs', 'headshotKills', 'heals',
#        'killPlace', 'killPoints', 'kills', 'killStreaks', 'longestKill',
#        'matchDuration', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills',
#        'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints',
#        'winPlacePerc'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'matchType'], dtype='object')

# %% [markdown]
# ### Checking outliers for each numerical column

# %%
df1.boxplot(figsize=(30,25))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# ### Understanding the probability and frequency distribution of each numerical column

# %%
df1.hist(figsize=(20,20))
plt.show()

# %%
sns.distplot(df1['assists'])
# Out:
# <AxesSubplot:xlabel='assists', ylabel='Density'>

# %%
sns.distplot(df1['boosts'])
# Out:
# <AxesSubplot:xlabel='boosts', ylabel='Density'>

# %%
sns.distplot(df1['damageDealt'])
# Out:
# <AxesSubplot:xlabel='damageDealt', ylabel='Density'>

# %%
sns.distplot(df1['DBNOs'])
# Out:
# <AxesSubplot:xlabel='DBNOs', ylabel='Density'>

# %%
sns.distplot(df1['headshotKills'])
# Out:
# <AxesSubplot:xlabel='headshotKills', ylabel='Density'>

# %%
sns.distplot(df1['heals'])
# Out:
# <AxesSubplot:xlabel='heals', ylabel='Density'>

# %%
sns.distplot(df1['killPlace'])
# Out:
# <AxesSubplot:xlabel='killPlace', ylabel='Density'>

# %%
sns.distplot(df1['killPoints'])
# Out:
# <AxesSubplot:xlabel='killPoints', ylabel='Density'>

# %%
sns.distplot(df1['kills'])
# Out:
# <AxesSubplot:xlabel='kills', ylabel='Density'>

# %%
sns.distplot(df1['killStreaks'])
# Out:
# <AxesSubplot:xlabel='killStreaks', ylabel='Density'>

# %%
sns.distplot(df1['longestKill'])
# Out:
# <AxesSubplot:xlabel='longestKill', ylabel='Density'>

# %%
sns.distplot(df1['matchDuration'])
# Out:
# <AxesSubplot:xlabel='matchDuration', ylabel='Density'>

# %%
sns.distplot(df1['maxPlace'])
# Out:
# <AxesSubplot:xlabel='maxPlace', ylabel='Density'>

# %%
sns.distplot(df1['numGroups'])
# Out:
# <AxesSubplot:xlabel='numGroups', ylabel='Density'>

# %%
sns.distplot(df1['rankPoints'])
# Out:
# <AxesSubplot:xlabel='rankPoints', ylabel='Density'>

# %%
sns.distplot(df1['revives'])
# Out:
# <AxesSubplot:xlabel='revives', ylabel='Density'>

# %%
sns.distplot(df1['rideDistance'])
# Out:
# <AxesSubplot:xlabel='rideDistance', ylabel='Density'>

# %%
sns.distplot(df1['roadKills'])
# Out:
# <AxesSubplot:xlabel='roadKills', ylabel='Density'>

# %%
sns.distplot(df1['swimDistance'])
# Out:
# <AxesSubplot:xlabel='swimDistance', ylabel='Density'>

# %%
sns.distplot(df1['teamKills'])
# Out:
# <AxesSubplot:xlabel='teamKills', ylabel='Density'>

# %%
sns.distplot(df1['vehicleDestroys'])
# Out:
# <AxesSubplot:xlabel='vehicleDestroys', ylabel='Density'>

# %%
sns.distplot(df1['walkDistance'])
# Out:
# <AxesSubplot:xlabel='walkDistance', ylabel='Density'>

# %%
sns.distplot(df1['weaponsAcquired'])
# Out:
# <AxesSubplot:xlabel='weaponsAcquired', ylabel='Density'>

# %%
sns.distplot(df1['winPoints'])
# Out:
# <AxesSubplot:xlabel='winPoints', ylabel='Density'>

# %%
df['Id'].nunique()
# Out:
# 1111742

# %%
df['groupId'].nunique()
# Out:
# 870622

# %%
df['matchId'].nunique()
# Out:
# 47951

# %%
df['matchType'].nunique()
# Out:
# 16

# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# ### Discover the relationships between numerical columns

# %%
df1.corr()
# Out:
#                   assists    boosts  damageDealt     DBNOs  headshotKills  \
# assists          1.000000  0.306582     0.409369  0.302200       0.199487
# boosts           0.306582  1.000000     0.519600  0.357903       0.331536
# damageDealt      0.409369  0.519600     1.000000  0.735084       0.613306
# DBNOs            0.302200  0.357903     0.735084  1.000000       0.467393
# headshotKills    0.199487  0.331536     0.613306  0.467393       1.000000
# heals            0.228456  0.535388     0.341620  0.265348       0.197936
# killPlace       -0.289984 -0.554046    -0.676134 -0.554858      -0.468079
# killPoints       0.038331  0.008992     0.050217  0.042139       0.024203
# kills            0.322068  0.499478     0.889038  0.706211       0.673739
# killStreaks      0.243386  0.403484     0.703222  0.646344       0.513207
# longestKill      0.260407  0.421444     0.561656  0.449521       0.444803
# matchDuration   -0.019399  0.071471    -0.007605 -0.014080      -0.018887
# ...

# %%
plt.figure(figsize=(20,20))

sns.heatmap(df1.corr(),linewidths=.1,cmap="YlGnBu", annot=True)

plt.yticks(rotation=0);

# %% [markdown]
# ### kill point and win point are 98% correlated & win point and rankpoints are 99% correlated

# %% [markdown]
# ### Understanding the frequency distribution of each categorical Column

# %%
df['Id'][df['longestKill'].value_counts()[:5]]
# Out:
# 634407    1b7cdd2a715cc3
# 125       60ec52e958784f
# 125       60ec52e958784f
# 125       60ec52e958784f
# 123       1d33a2f49fcb56
# 123       1d33a2f49fcb56
# 122       16df4467dd1909
# 122       16df4467dd1909
# 121       7ffd171596d75a
# 120       850d7dd0f40d3a
# 119       bd794d03835a53
# 119       bd794d03835a53
# 118       f54a424f97b6b9
# 118       f54a424f97b6b9
# 118       f54a424f97b6b9
# 117       95c0096f44f2fe
# 117       95c0096f44f2fe
# 116       a5e80ed7d3b235
# 115       cea183a5cdd126
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 112       443eedfac2705e
# 112       443eedfac2705e
# 112       443eedfac2705e
# 112       443eedfac2705e
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# ...

# %%
df['Id'][df['kills'].value_counts()[:10]]
# Out:
# 632149    e4de65e1c164db
# 232156    3a879c00a7a677
# 118274    fad26ad8f76030
# 58026     85433a03f32d59
# 31302     18541b0b8afa40
# 16600     4cfb1ba6c431df
# 9429      f3c86c23cdabe6
# 5458      29794303921891
# 3139      8e56568577bb96
# 1934      8f2c8bcc79146c
# Name: Id, dtype: object

# %%
df['Id'][df['longestKill'].value_counts()[:10]]
# Out:
# 634407    1b7cdd2a715cc3
# 125       60ec52e958784f
# 125       60ec52e958784f
# 125       60ec52e958784f
# 123       1d33a2f49fcb56
# 123       1d33a2f49fcb56
# 122       16df4467dd1909
# 122       16df4467dd1909
# 121       7ffd171596d75a
# 120       850d7dd0f40d3a
# 119       bd794d03835a53
# 119       bd794d03835a53
# 118       f54a424f97b6b9
# 118       f54a424f97b6b9
# 118       f54a424f97b6b9
# 117       95c0096f44f2fe
# 117       95c0096f44f2fe
# 116       a5e80ed7d3b235
# 115       cea183a5cdd126
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 112       443eedfac2705e
# 112       443eedfac2705e
# 112       443eedfac2705e
# 112       443eedfac2705e
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# ...

# %%
df['Id'][df['killStreaks'].value_counts()[:10]]
# Out:
# 632149    e4de65e1c164db
# 368901    d48a206c6e407d
# 97301     135e047ead9587
# 11708     156d50ddd390b7
# 1520      c30cd3b84e7629
# 84        a4296053b32967
# 36        b9166170a332f6
# 16        681756a82a8567
# 10        cf3fc190ef0636
# 7         c264a5ce0d4ca1
# Name: Id, dtype: object

# %%
df['Id'][df['longestKill'].value_counts()[:10]]
# Out:
# 634407    1b7cdd2a715cc3
# 125       60ec52e958784f
# 125       60ec52e958784f
# 125       60ec52e958784f
# 123       1d33a2f49fcb56
# 123       1d33a2f49fcb56
# 122       16df4467dd1909
# 122       16df4467dd1909
# 121       7ffd171596d75a
# 120       850d7dd0f40d3a
# 119       bd794d03835a53
# 119       bd794d03835a53
# 118       f54a424f97b6b9
# 118       f54a424f97b6b9
# 118       f54a424f97b6b9
# 117       95c0096f44f2fe
# 117       95c0096f44f2fe
# 116       a5e80ed7d3b235
# 115       cea183a5cdd126
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 114       04e4ba261679d3
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 113       e50fa7e0cf4726
# 112       443eedfac2705e
# 112       443eedfac2705e
# 112       443eedfac2705e
# 112       443eedfac2705e
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# 111       e062d8336facf2
# ...
